# %% [markdown]
# # INTRODUCTION
# This notebook is creating the contrast normalisation function.

# %%
from PIL import Image
import PIL.ImageOps as ImageOps
import matplotlib.pyplot as plt

# %%
with Image.open("../data/image50/8863/0/8863_idx5_x51_y1251_class0.png") as im:
    im.show()

# %% [markdown]
# ## autocontrast (Does not work)

# %%
# Subplt autocontrast and original image
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(im, cmap='gray')
ax[0].set_title('Original Image')
ax[0].axis('off')
ax[1].imshow(ImageOps.autocontrast(im), cmap='gray')
ax[1].set_title('Autocontrast Image')
ax[1].axis('off')
# ImageOps.autocontrast(im, cutoff=0, ignore=None, preserve_tone=False)
# Out:
# (np.float64(-0.5), np.float64(49.5), np.float64(49.5), np.float64(-0.5))

# %% [markdown]
# **CONCLUSION**: This does not help me in my problematics. I want to normalise all the images in a uniform way.

# %%
# mean distribution for
